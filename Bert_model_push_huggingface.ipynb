# %% [markdown]
# ***bert_main.py*** :
# contient les fonctions :
# - chargement du dataset, de preprocessing
# - d'encodage des labels
# - de separation des données en train et test
# - d'entrainement du modele
# Une fois le modele entrainé, il est sauvergadé sur le Drive de Google
#
#
# ***bert_push_to_huggingface.py*** :
#
# permet de se connecter a huggingface et de pusher le modele sauvegardé
#
#
# ***le lien huggingface est :***
# https://huggingface.co/etonkou/bert-classification

# %%
# Installation transformer
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 57.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.1 MB/s eta 0:00:00
# ...

# %%
# %run bert_main.py
# Out:
# Mounted at /content/drive
# ...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   5%|▌         | 33/617 [13:32<3:59:33, 24.61s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/bert_main.py in <module>
#     151
#     152     # train model
# --> 153     train(model,NUM_EPOCHS,LEARNING_RATE)
#     154
#     155     # save model
#
# /content/bert_main.py in train(model, num_epochs, lr)
#      71             batch_inputs, batch_attention_mask, batch_labels = batch
#      72             optimizer.zero_grad()
# ---> 73             outputs = model(input_ids=batch_inputs, attention_mask = batch_attention_mask, labels=batch_labels)
# ...

# %%
# push saved model to huggingface
# %run bert_push_to_huggingface.py
